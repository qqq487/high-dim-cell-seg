# %%
import json
import os
# import torch
import cv2 
import numpy as np

# %%
a = np.zeros((3,2,4))

# %%
a.shape
# Out:
# (3, 2, 4)

# %%
def which_is_longer(feature_coords):

    num_layers = 0
    f0 = feature_coords
    while type(f0) == list:
        f0 = f0[0]
        num_layers +=1
        
    temp = feature_coords
    
    if num_layers > 3:
        for i in range(num_layers-3):
            processed_feature_coords = temp
            temp = temp[0]

    elif num_layers == 3:
        processed_feature_coords = temp
    
    else:
        processed_feature_coords = temp

    
    temp = 0
    longest = 0
    
    for long_idx, i_dont_know_why in enumerate(processed_feature_coords):
        while len(i_dont_know_why) == 1:
            i_dont_know_why = i_dont_know_why[0]

        if len(i_dont_know_why) > temp:
            temp = len(i_dont_know_why)
            longest = long_idx
    
    return longest


def process_features_coords(features):
    
    processed_coord_list = []
    
    assert type(features) == list
        
    for feature in features:
        #print(type(feature['geometry']['coordinates']))
        
        if type(feature['geometry']['coordinates']) == list:
            
            f_id = which_is_longer(feature['geometry']['coordinates'])

            processed_coord = feature['geometry']['coordinates'][f_id]
            
            num_layers = 0
            f0 = processed_coord
            while type(f0) == list:
                f0 = f0[0]
                num_layers +=1
                
            if num_layers == 3:

                processed_coord = processed_coord[0]
                
        processed_coord_list.append(processed_coord)
        
    return processed_coord_list

# %% [markdown]
# ## gernerate and move Masks

# %%
folder_list = os.listdir("./seperate_labeled/")
folder_list
# Out:
# ['mouse4',
#  'human4',
#  'mouse13',
#  'human1',
#  'mouse0',
#  'human10',
#  'reg012_4',
#  'human0',
#  'mouse23',
#  'reg012_8']

# %%
for folder_name in folder_list:
    #folder_name = "human1"

    root_folder = "./seperate_labeled/{}/".format(folder_name)

    channel_list = os.listdir(root_folder)



    img_size = (756,672)

    threshold = 0.6

    res_cell_list = []



    for idx, channel in enumerate(channel_list): ## each channel
        one_channel_result = np.zeros(img_size)
        cell_count = 1

        if channel != "useless":

            print("================="+channel+"=====================")
            ann_json_path = os.path.join(root_folder,channel,"annotations.json")
            with open(ann_json_path) as f:
                data_dict = json.load(f)

            list_of_point_list = process_features_coords(data_dict)
            print(len(list_of_point_list))

            tmp_ch_cell_list = [] ## record one ch cells that have small iou with res_cell_list. 

            for cell in list_of_point_list:

                add_new = True

                cell_points = np.array(cell).astype(int) ## each cell

                cell_mask = cv2.drawContours(np.zeros((img_size[0], img_size[1]), np.uint8), [cell_points], -1, 255, cv2.FILLED)

                for i in range(img_size[0]):
                    for j in range(img_size[1]):
                        if cell_mask[i][j] != 0:
                            one_channel_result[i][j] = cell_count

                cell_count += 1

                # cell_mask_contours, _ = cv2.findContours(mask_and, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

                cell_mask_area = cv2.contourArea(cell_points)

                if len(res_cell_list) == 0:
                    tmp_ch_cell_list.append(cell)

                else:

                    for checked_cell in res_cell_list:

                        res_points = np.array(checked_cell).astype(int) ## each cell

                        res_mask = cv2.drawContours(np.zeros((img_size[0], img_size[1]), np.uint8), [res_points], -1, 255, cv2.FILLED)

                        res_mask_area = cv2.contourArea(res_points)


                        mask_and = cv2.bitwise_and(res_mask, cell_mask)
                        mask_and_contours, _ = cv2.findContours(mask_and, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

                        if len(mask_and_contours)>0:
                            mask_and_area = cv2.contourArea(mask_and_contours[0])

                            new_cell_area_ratio = mask_and_area/cell_mask_area
                            checked_cell_area_ratio = mask_and_area/res_mask_area

                            if max(new_cell_area_ratio,checked_cell_area_ratio) > threshold:
                                if res_mask_area > cell_mask_area:
                                    add_new = False
                                else:
                                    res_cell_list.remove(checked_cell)

                    if add_new == True:
                        tmp_ch_cell_list.append(cell)
            #print("tmp_ch_cell_list = ",tmp_ch_cell_list) 
            res_cell_list.extend(tmp_ch_cell_list)
        np.save(root_folder+channel+"/"+channel+".npy", one_channel_result)
        one_channel_mask_img = Image.fromarray(one_channel_result).convert("I")
        one_channel_mask_img.save("./NTUH_train/{}_{}_masks.png".format(folder_name, channel))
# img_size = (756,672)

# test_mask = np.zeros((img_size[0], img_size[1]), np.uint8)

# for test_cell in res_cell_list:


# 	test_cell_points = np.array(test_cell).astype(int) ## each cell

# 	test_mask = cv2.drawContours(test_mask, [test_cell_points], -1, 255, cv2.FILLED)

# cv2.imwrite("{}.png".format(json_name),test_mask)
# Out:
# =================0701_reg001_cyc012_ch003_CD4_4=====================
# 4
# =================0701_reg001_cyc009_ch004_ScaI_4=====================
# 2
# =================0701_reg001_cyc006_ch003_Ly6C_4=====================
# 2
# =================0701_reg001_cyc004_ch003_CD8_4=====================
# 7
# =================0701_reg001_cyc007_ch004_CD45_4=====================
# 22
# =================0701_reg001_cyc013_ch004_N-Cadherin_4=====================
# 156
# =================reg005_reg005_cyc004_ch002_CD45_4=====================
# 96
# =================reg005_reg005_cyc003_ch004_CD4_4=====================
# 83
# =================reg005_reg005_cyc017_ch004_NAKATP_4=====================
# 155
# =================reg005_reg005_cyc014_ch003_CD40_4=====================
# 144
# =================reg005_reg005_cyc006_ch004_CD206_4=====================
# 37
# =================0701_reg001_cyc006_ch003_Ly6C_13=====================
# 91
# =================0701_reg001_cyc008_ch003_CD19_13=====================
# 98
# =================0701_reg001_cyc012_ch003_CD4_13=====================
# 124
# =================0701_reg001_cyc013_ch004_N-Cadherin_13=====================
# 3
# =================0701_reg001_cyc004_ch003_CD8_13=====================
# 95
# =================0701_reg001_cyc005_ch003_CD11b_13=====================
# 11
# =================0701_reg001_cyc009_ch004_ScaI_13=====================
# 460
# =================0701_reg001_cyc007_ch004_CD45_13=====================
# 321
# =================reg005_reg005_cyc017_ch004_NAKATP_1=====================
# 365
# =================reg005_reg005_cyc006_ch004_CD206_1=====================
# 32
# =================reg005_reg005_cyc008_ch004_CD11b_1=====================
# 89
# =================reg005_reg005_cyc004_ch002_CD45_1=====================
# 41
# =================reg005_reg005_cyc014_ch003_CD40_1=====================
# 71
# =================reg005_reg005_cyc003_ch004_CD4_1=====================
# 46
# =================6_0701_reg001_cyc008_ch003_CD19_0=====================
# 1
# =================1_0701_reg001_cyc012_ch003_CD4_0=====================
# 7
# =================2_0701_reg001_cyc009_ch004_ScaI_0=====================
# 1
# =================0_0701_reg001_cyc007_ch004_CD45_0=====================
# 34
# =================3_0701_reg001_cyc005_ch003_CD11b_0=====================
# 1
# =================7_0701_reg001_cyc006_ch003_Ly6C_0=====================
# 2
# =================8_0701_reg001_cyc013_ch004_N-Cadherin_0=====================
# 164
# =================reg005_reg005_cyc006_ch004_CD206_10=====================
# 46
# =================reg005_reg005_cyc003_ch004_CD4_10=====================
# 10
# =================reg005_reg005_cyc017_ch004_NAKATP_10=====================
# 415
# =================reg005_reg005_cyc014_ch003_CD40_10=====================
# 22
# =================reg005_reg005_cyc004_ch002_CD45_10=====================
# 18
# =================reg005_reg005_cyc008_ch004_CD11b_10=====================
# 140
# =================reg012_reg012_cyc008_ch004_CD11b_4=====================
# 19
# =================reg012_reg012_cyc006_ch004_CD206_4=====================
# 38
# =================reg012_reg012_cyc017_ch004_NAKATP_4=====================
# 213
# =================reg012_reg012_cyc003_ch004_CD4_4=====================
# 43
# =================reg012_reg012_cyc004_ch002_CD45_4=====================
# 13
# =================reg012_reg012_cyc014_ch003_CD40_4=====================
# 45
# =================reg006_reg006_cyc017_ch004_NAKATP_0=====================
# 133
# =================reg006_reg006_cyc004_ch002_CD45_0=====================
# 19
# =================reg006_reg006_cyc014_ch003_CD40_0=====================
# 92
# =================reg006_reg006_cyc006_ch004_CD206_0=====================
# 26
# =================reg006_reg006_cyc008_ch004_CD11b_0=====================
# 6
# =================reg006_reg006_cyc003_ch004_CD4_0=====================
# 36
# =================0701_reg001_cyc007_ch004_CD45_23=====================
# 110
# =================0701_reg001_cyc005_ch003_CD11b_23=====================
# 11
# =================0701_reg001_cyc008_ch003_CD19_23=====================
# 10
# =================0701_reg001_cyc004_ch003_CD8_23=====================
# 24
# =================0701_reg001_cyc009_ch004_ScaI_23=====================
# 78
# =================0701_reg001_cyc013_ch004_N-Cadherin_23=====================
# 207
# =================0701_reg001_cyc012_ch003_CD4_23=====================
# 33
# =================0701_reg001_cyc006_ch003_Ly6C_23=====================
# 9
# =================reg012_reg012_cyc006_ch004_CD206_8=====================
# 25
# =================reg012_reg012_cyc008_ch004_CD11b_8=====================
# 2
# =================reg012_reg012_cyc004_ch002_CD45_8=====================
# 2
# =================reg012_reg012_cyc003_ch004_CD4_8=====================
# 16
# =================reg012_reg012_cyc017_ch004_NAKATP_8=====================
# 464
# =================reg012_reg012_cyc014_ch003_CD40_8=====================
# 10

# %% [markdown]
# ## move imgs

# %%
test_folder_list = os.listdir("../unet/test_data/test_imgs_multi_with_nuclei/")

# %%
test_folder_list.remove(".ipynb_checkpoints")

# %%
test_folder_list
# Out:
# ['val_human10',
#  'selected_mouse17',
#  'mouse17',
#  'selected_human4',
#  'train_mouse4',
#  'selected_mouse13',
#  'train_mouse13',
#  'selected_mouse23',
#  'mouse7',
#  'mouse21',
#  'train_mouse0',
#  'train_human1',
#  'test_human4',
#  'val_reg012_8',
#  'selected_mouse4',
#  'train_reg012_4',
#  'selected_mouse7',
#  'selected_mouse21',
#  'train_human0',
#  'test_mouse23',
#  '0913_reg013_18',
#  '20201112_tonsil_multicycle_90',
#  '0913_reg016_11',
#  '0913_reg013_8']

# %%
for folder_name in test_folder_list:
    #folder_name = "human1"

    root_folder = "../unet/test_data/test_imgs_multi_with_nuclei/{}/".format(folder_name)

    channel_list = os.listdir(root_folder)

    for idx, channel in enumerate(channel_list): ## each channel
        if channel != ".ipynb_checkpoints":
            print("Now {}_{}".format(folder_name,channel))
            img_path = root_folder+channel
            img = cv2.imread(img_path,0)
            cv2.imwrite("./NTUH_test/{}_{}".format(folder_name,channel),img)
# Out:
# Now val_human10_reg005_cyc014_ch004_Podoplanin_10.png
# Now val_human10_reg005_cyc013_ch003_E-Cadherin_10.png
# Now val_human10_reg005_cyc013_ch004_HSP-70_10.png
# Now val_human10_reg005_cyc003_ch004_CD4_10.png
# Now val_human10_reg005_cyc016_ch003_Granzyme B_10.png
# Now val_human10_reg005_cyc019_ch003_CD38_10.png
# Now val_human10_reg005_cyc010_ch003_CD45RO_10.png
# Now val_human10_reg005_cyc019_ch004_Vimentin_10.png
# Now val_human10_reg005_cyc011_ch004_CD45RA_10.png
# Now val_human10_reg005_cyc006_ch003_PDL2_10.png
# Now val_human10_reg005_cyc005_ch003_CD15_10.png
# Now val_human10_reg005_cyc017_ch003_CD11C_10.png
# Now val_human10_reg005_cyc005_ch004_GATA3_10.png
# Now val_human10_reg005_cyc007_ch004_TP53_10.png
# Now val_human10_reg005_cyc010_ch004_TIM-3_10.png
# Now val_human10_reg005_reg005_cyc017_ch004_NAKATP_10.tif
# Now val_human10_reg005_cyc018_ch003_CD34_10.png
# Now val_human10_reg005_cyc002_ch004_PD1_10.png
# Now val_human10_reg005_cyc003_ch002_KI67_10.png
# Now val_human10_reg005_cyc015_ch004_A-SMA_10.png
# Now val_human10_reg005_reg005_cyc008_ch004_CD11b_10.tif
# Now val_human10_reg005_cyc012_ch003_MPO_10.png
# Now val_human10_reg005_cyc007_ch003_ICOS_10.png
# Now val_human10_reg005_reg005_cyc001_ch001_DAPI-01_10.tif
# Now val_human10_reg005_cyc008_ch004_CD11b_10.png
# Now val_human10_reg005_cyc010_ch002_HSA_10.png
# Now val_human10_reg005_cyc002_ch003_PDL1_10.png
# Now val_human10_reg005_cyc015_ch003_CD31_10.png
# Now val_human10_reg005_cyc014_ch003_CD40_10.png
# Now val_human10_reg005_cyc004_ch004_CD3e_10.png
# Now val_human10_reg005_cyc018_ch004_Galectin-9_10.png
# Now val_human10_reg005_reg005_cyc014_ch003_CD40_10.tif
# Now val_human10_reg005_cyc003_ch003_CD8_10.png
# Now val_human10_reg005_cyc004_ch003_FOXP3_10.png
# Now val_human10_reg005_cyc004_ch002_CD45_10.png
# Now val_human10_reg005_cyc009_ch004_B-Catenin_10.png
# Now val_human10_reg005_reg005_cyc006_ch004_CD206_10.tif
# Now val_human10_reg005_cyc017_ch004_NAKATP_10.png
# Now selected_human4_reg005_reg005_cyc017_ch004_NAKATP_4.tif
# Now selected_human4_reg005_reg005_cyc004_ch002_CD45_4.tif
# Now train_mouse4_reg001_cyc005_ch004_MHCII_4.png
# Now train_mouse4_reg001_cyc003_ch003_CD3_4.png
# Now train_mouse4_reg001_cyc006_ch004_CD44_4.png
# Now train_mouse4_reg001_cyc004_ch004_PDL1_4.png
# Now train_mouse4_reg001_cyc003_ch004_CD169_4.png
# Now train_mouse4_reg001_cyc010_ch004_CD38_4.png
# Now train_mouse4_reg001_cyc013_ch003_Endomucin_4.png
# Now train_mouse4_reg001_cyc008_ch003_CD19_4.png
# Now train_mouse4_reg001_cyc009_ch003_CD11c_4.png
# Now train_mouse4_reg001_cyc013_ch004_N-Cadherin_4.png
# Now train_mouse4_reg001_cyc002_ch003_F4-80_4.png
# Now train_mouse4_reg001_cyc007_ch003_pATM_4.png
# Now train_mouse4_reg001_cyc006_ch003_Ly6C_4.png
# Now train_mouse4_reg001_cyc004_ch003_CD8_4.png
# Now train_mouse4_reg001_cyc003_ch002_pH2AX_4.png
# Now train_mouse4_reg001_cyc002_ch004_PD1_4.png
# Now train_mouse4_reg001_cyc011_ch004_CD24_4.png
# Now train_mouse4_reg001_cyc010_ch003_Ly6G_4.png
# Now train_mouse4_reg001_cyc007_ch002_Ki67_4.png
# Now train_mouse4_reg001_cyc011_ch003_CD206_4.png
# Now train_mouse4_reg001_cyc001_ch001_DAPI-01_4.png
# Now train_mouse4_reg001_cyc005_ch003_CD11b_4.png
# Now train_mouse4_reg001_cyc012_ch004_ATPase_4.png
# Now train_mouse4_reg001_cyc007_ch004_CD45_4.png
# Now train_mouse4_reg001_cyc009_ch004_ScaI_4.png
# Now train_mouse4_reg001_cyc012_ch003_CD4_4.png
# Now selected_mouse13_0701_reg001_cyc002_ch001_DAPI.png
# Now selected_mouse13_0701_reg001_cyc006_ch003_Ly6C.png
# Now selected_mouse13_0701_reg001_cyc009_ch004_ScaI.png
# Now selected_mouse13_0701_reg001_cyc007_ch004_CD45.png
# Now selected_mouse13_0701_reg001_cyc012_ch003_CD4.png
# Now selected_mouse13_0701_reg001_cyc013_ch004_N-Cadherin.png
# Now train_mouse13_reg001_cyc007_ch003_pATM_13.png
# Now train_mouse13_reg001_cyc007_ch004_CD45_13.png
# Now train_mouse13_reg001_cyc012_ch004_ATPase_13.png
# Now train_mouse13_reg001_cyc010_ch004_CD38_13.png
# Now train_mouse13_reg001_cyc001_ch001_DAPI-01_13.png
# Now train_mouse13_reg001_cyc002_ch003_F4-80_13.png
# Now train_mouse13_reg001_cyc006_ch004_CD44_13.png
# Now train_mouse13_reg001_cyc003_ch004_CD169_13.png
# Now train_mouse13_reg001_cyc005_ch003_CD11b_13.png
# Now train_mouse13_reg001_cyc011_ch004_CD24_13.png
# Now train_mouse13_reg001_cyc005_ch004_MHCII_13.png
# Now train_mouse13_reg001_cyc003_ch003_CD3_13.png
# Now train_mouse13_reg001_cyc007_ch002_Ki67_13.png
# Now mouse21_reg001_cyc006_ch004_CD44_21.png
# Now mouse21_reg001_cyc010_ch003_Ly6G_21.png
# Now mouse21_reg001_cyc002_ch003_F4-80_21.png
# Now mouse21_reg001_cyc005_ch003_CD11b_21.png
# Now mouse21_reg001_cyc005_ch004_MHCII_21.png
# Now mouse21_reg001_cyc012_ch003_CD4_21.png
# Now mouse21_reg001_cyc011_ch003_CD206_21.png
# Now mouse21_reg001_cyc004_ch004_PDL1_21.png
# Now mouse21_reg001_cyc009_ch003_CD11c_21.png
# Now mouse21_reg001_cyc008_ch003_CD19_21.png
# Now mouse21_reg001_cyc007_ch004_CD45_21.png
# Now mouse21_reg001_cyc007_ch003_pATM_21.png
# Now mouse21_reg001_cyc009_ch004_ScaI_21.png
# Now mouse21_reg001_cyc002_ch004_PD1_21.png
# Now mouse21_reg001_cyc013_ch003_Endomucin_21.png
# Now mouse21_reg001_cyc010_ch004_CD38_21.png
# Now mouse21_reg001_cyc003_ch004_CD169_21.png
# Now mouse21_reg001_cyc012_ch004_ATPase_21.png
# Now mouse21_reg001_cyc013_ch004_N-Cadherin_21.png
# Now mouse21_reg001_cyc003_ch003_CD3_21.png
# Now mouse21_reg001_cyc001_ch001_DAPI-01_21.png
# Now mouse21_reg001_cyc011_ch004_CD24_21.png
# Now mouse21_reg001_cyc003_ch002_pH2AX_21.png
# Now train_mouse0_reg001_cyc013_ch004_N-Cadherin_0.png
# Now train_mouse0_reg001_cyc012_ch003_CD4_0.png
# Now train_mouse0_reg001_cyc002_ch003_F4-80_0.png
# Now train_mouse0_reg001_cyc010_ch003_Ly6G_0.png
# Now train_mouse0_reg001_cyc001_ch001_DAPI-01_0.png
# Now train_mouse0_reg001_cyc003_ch002_pH2AX_0.png
# Now train_mouse0_reg001_cyc008_ch003_CD19_0.png
# Now train_mouse0_reg001_cyc005_ch004_MHCII_0.png
# Now train_mouse0_reg001_cyc005_ch003_CD11b_0.png
# Now train_mouse0_reg001_cyc013_ch003_Endomucin_0.png
# Now train_mouse0_reg001_cyc011_ch004_CD24_0.png
# Now train_mouse0_reg001_cyc002_ch004_PD1_0.png
# Now train_mouse0_reg001_cyc003_ch004_CD169_0.png
# Now train_mouse0_reg001_cyc007_ch002_Ki67_0.png
# Now train_mouse0_reg001_cyc009_ch004_ScaI_0.png
# Now train_mouse0_reg001_cyc007_ch003_pATM_0.png
# Now train_mouse0_reg001_cyc004_ch003_CD8_0.png
# Now train_mouse0_reg001_cyc010_ch004_CD38_0.png
# Now train_mouse0_reg001_cyc011_ch003_CD206_0.png
# Now train_mouse0_reg001_cyc003_ch003_CD3_0.png
# Now train_mouse0_reg001_cyc012_ch004_ATPase_0.png
# Now train_mouse0_reg001_cyc006_ch003_Ly6C_0.png
# Now train_mouse0_reg001_cyc007_ch004_CD45_0.png
# Now train_mouse0_reg001_cyc006_ch004_CD44_0.png
# Now train_mouse0_reg001_cyc004_ch004_PDL1_0.png
# Now train_mouse0_reg001_cyc009_ch003_CD11c_0.png
# Now train_human1_reg005_reg005_cyc004_ch002_CD45_1.tif
# Now train_human1_reg005_cyc015_ch003_CD31_1.png
# Now train_human1_reg005_cyc010_ch002_HSA_1.png
# Now train_human1_reg005_cyc012_ch003_MPO_1.png
# Now train_human1_reg005_cyc013_ch003_E-Cadherin_1.png
# Now train_human1_reg005_cyc004_ch002_CD45_1.png
# Now train_human1_reg005_cyc008_ch003_CD56_1.png
# Now train_human1_reg005_cyc008_ch004_CD11b_1.png
# Now train_human1_reg005_cyc011_ch003_CD163_1.png
# Now train_human1_reg005_cyc005_ch003_CD15_1.png
# Now train_human1_reg005_cyc011_ch004_CD45RA_1.png
# Now train_human1_reg005_cyc010_ch004_TIM-3_1.png
# Now train_human1_reg005_reg005_cyc003_ch004_CD4_1.tif
# Now train_human1_reg005_cyc006_ch002_HLADR_1.png
# Now train_human1_reg005_cyc014_ch004_Podoplanin_1.png
# Now train_human1_reg005_reg005_cyc006_ch004_CD206_1.tif
# Now train_human1_reg005_cyc012_ch004_Panck_1.png
# Now train_human1_reg005_cyc009_ch004_B-Catenin_1.png
# Now train_human1_reg005_cyc002_ch002_CD20_1.png
# Now train_human1_reg005_cyc011_ch002_CD68_1.png
# Now train_human1_reg005_cyc016_ch004_CD21_1.png
# Now train_human1_reg005_cyc017_ch003_CD11C_1.png
# Now train_human1_reg005_cyc005_ch004_GATA3_1.png
# Now train_human1_reg005_cyc002_ch004_PD1_1.png
# Now train_human1_reg005_cyc016_ch003_Granzyme B_1.png
# Now train_human1_reg005_cyc006_ch003_PDL2_1.png
# Now train_human1_reg005_cyc001_ch001_DAPI-01_1.png
# Now train_human1_reg005_cyc003_ch004_CD4_1.png
# Now train_human1_reg005_cyc009_ch003_CD57_1.png
# Now train_human1_reg005_cyc015_ch004_A-SMA_1.png
# Now train_human1_reg005_cyc009_ch002_CK8CK18_1.png
# Now train_human1_reg005_cyc007_ch003_ICOS_1.png
# Now train_human1_reg005_cyc003_ch002_KI67_1.png
# Now train_human1_reg005_cyc003_ch003_CD8_1.png
# Now train_human1_reg005_cyc007_ch004_TP53_1.png
# Now train_human1_reg005_cyc004_ch004_CD3e_1.png
# Now train_human1_reg005_cyc019_ch004_Vimentin_1.png
# Now train_human1_reg005_cyc006_ch004_CD206_1.png
# Now train_human1_reg005_cyc004_ch003_FOXP3_1.png
# Now train_human1_reg005_reg005_cyc008_ch004_CD11b_1.tif
# Now train_human1_reg005_reg005_cyc014_ch003_CD40_1.tif
# Now train_human1_reg005_cyc002_ch003_PDL1_1.png
# Now train_human1_reg005_reg005_cyc017_ch004_NAKATP_1.tif
# Now train_human1_reg005_cyc019_ch003_CD38_1.png
# Now train_human1_reg005_cyc014_ch003_CD40_1.png
# Now train_human1_reg005_cyc018_ch003_CD34_1.png
# Now train_human1_reg005_cyc018_ch004_Galectin-9_1.png
# Now train_human1_reg005_cyc010_ch003_CD45RO_1.png
# Now train_human1_reg005_cyc017_ch004_NAKATP_1.png
# Now train_human1_reg005_cyc013_ch004_HSP-70_1.png
# Now train_human1_reg005_reg005_cyc001_ch001_DAPI-01_1.tif
# Now test_human4_reg005_cyc004_ch004_CD3e_4.png
# Now test_human4_reg005_cyc008_ch004_CD11b_4.png
# Now test_human4_reg005_cyc010_ch004_TIM-3_4.png
# Now test_human4_reg005_cyc019_ch004_Vimentin_4.png
# Now test_human4_reg005_cyc009_ch004_B-Catenin_4.png
# Now test_human4_reg005_cyc003_ch002_KI67_4.png
# Now test_human4_reg005_cyc012_ch004_Panck_4.png
# Now test_human4_reg005_cyc011_ch002_CD68_4.png
# Now test_human4_reg005_cyc007_ch004_TP53_4.png
# Now test_human4_reg005_cyc004_ch002_CD45_4.png
# Now test_human4_reg005_cyc003_ch003_CD8_4.png
# Now test_human4_reg005_cyc013_ch003_E-Cadherin_4.png
# Now test_human4_reg005_cyc004_ch003_FOXP3_4.png
# Now test_human4_reg005_cyc016_ch003_Granzyme B_4.png
# Now test_human4_reg005_cyc006_ch002_HLADR_4.png
# Now test_human4_reg005_cyc015_ch004_A-SMA_4.png
# Now test_human4_reg005_cyc012_ch003_MPO_4.png
# Now test_human4_reg005_cyc008_ch003_CD56_4.png
# Now test_human4_reg005_cyc010_ch002_HSA_4.png
# Now test_human4_reg005_cyc006_ch003_PDL2_4.png
# Now test_human4_reg005_cyc009_ch002_CK8CK18_4.png
# Now test_human4_reg005_cyc014_ch003_CD40_4.png
# Now test_human4_reg005_cyc005_ch004_GATA3_4.png
# Now test_human4_reg005_cyc011_ch004_CD45RA_4.png
# Now test_human4_reg005_cyc015_ch003_CD31_4.png
# Now test_human4_reg005_cyc017_ch004_NAKATP_4.png
# Now test_human4_reg005_cyc002_ch003_PDL1_4.png
# Now test_human4_reg005_cyc005_ch003_CD15_4.png
# Now test_human4_reg005_cyc011_ch003_CD163_4.png
# Now test_human4_reg005_cyc006_ch004_CD206_4.png
# Now test_human4_reg005_cyc001_ch001_DAPI-01_4.png
# Now test_human4_reg005_cyc019_ch003_CD38_4.png
# Now test_human4_reg005_cyc017_ch003_CD11C_4.png
# Now test_human4_reg005_cyc010_ch003_CD45RO_4.png
# Now test_human4_reg005_cyc018_ch003_CD34_4.png
# Now test_human4_reg005_cyc013_ch004_HSP-70_4.png
# Now test_human4_reg005_cyc002_ch004_PD1_4.png
# Now test_human4_reg005_cyc014_ch004_Podoplanin_4.png
# Now test_human4_reg005_cyc018_ch004_Galectin-9_4.png
# Now test_human4_reg005_cyc002_ch002_CD20_4.png
# Now test_human4_reg005_cyc016_ch004_CD21_4.png
# Now test_human4_reg005_cyc003_ch004_CD4_4.png
# Now test_human4_reg005_cyc009_ch003_CD57_4.png
# Now test_human4_reg005_cyc007_ch003_ICOS_4.png
# Now val_reg012_8_reg012_cyc017_ch003_CD11C_8.png
# Now val_reg012_8_reg012_cyc009_ch003_CD57_8.png
# Now val_reg012_8_reg012_cyc009_ch004_B-Catenin_8.png
# Now val_reg012_8_reg012_cyc006_ch004_CD206_8.png
# Now val_reg012_8_reg012_cyc010_ch004_TIM-3_8.png
# Now val_reg012_8_reg012_cyc008_ch003_CD56_8.png
# Now val_reg012_8_reg012_cyc002_ch004_PD1_8.png
# Now val_reg012_8_reg012_cyc017_ch004_NAKATP_8.png
# Now val_reg012_8_reg012_cyc008_ch004_CD11b_8.png
# Now val_reg012_8_reg012_cyc013_ch003_E-Cadherin_8.png
# Now val_reg012_8_reg012_cyc012_ch004_Panck_8.png
# Now val_reg012_8_reg012_cyc006_ch002_HLADR_8.png
# Now val_reg012_8_reg012_cyc019_ch003_CD38_8.png
# Now val_reg012_8_reg012_cyc018_ch003_CD34_8.png
# Now val_reg012_8_reg012_cyc010_ch002_HSA_8.png
# Now val_reg012_8_reg012_cyc002_ch002_CD20_8.png
# Now val_reg012_8_reg012_cyc004_ch002_CD45_8.png
# Now val_reg012_8_reg012_cyc007_ch004_TP53_8.png
# Now val_reg012_8_reg012_cyc001_ch001_DAPI-01_8.png
# Now val_reg012_8_reg012_cyc016_ch003_Granzyme B_8.png
# Now val_reg012_8_reg012_cyc004_ch003_FOXP3_8.png
# Now val_reg012_8_reg012_cyc018_ch004_Galectin-9_8.png
# Now val_reg012_8_reg012_cyc015_ch004_A-SMA_8.png
# Now val_reg012_8_reg012_cyc016_ch004_CD21_8.png
# Now val_reg012_8_reg012_cyc011_ch004_CD45RA_8.png
# Now val_reg012_8_reg012_cyc007_ch003_ICOS_8.png
# Now val_reg012_8_reg012_cyc005_ch003_CD15_8.png
# Now val_reg012_8_reg012_cyc015_ch003_CD31_8.png
# Now val_reg012_8_reg012_cyc011_ch003_CD163_8.png
# Now val_reg012_8_reg012_cyc014_ch004_Podoplanin_8.png
# Now val_reg012_8_reg012_cyc002_ch003_PDL1_8.png
# Now val_reg012_8_reg012_cyc011_ch002_CD68_8.png
# Now val_reg012_8_reg012_cyc003_ch002_KI67_8.png
# Now val_reg012_8_reg012_cyc009_ch002_CK8CK18_8.png
# Now val_reg012_8_reg012_cyc003_ch003_CD8_8.png
# Now val_reg012_8_reg012_cyc013_ch004_HSP-70_8.png
# Now val_reg012_8_reg012_cyc012_ch003_MPO_8.png
# Now val_reg012_8_reg012_cyc006_ch003_PDL2_8.png
# Now val_reg012_8_reg012_cyc003_ch004_CD4_8.png
# Now val_reg012_8_reg012_cyc005_ch004_GATA3_8.png
# Now val_reg012_8_reg012_cyc004_ch004_CD3e_8.png
# Now val_reg012_8_reg012_cyc010_ch003_CD45RO_8.png
# Now val_reg012_8_reg012_cyc019_ch004_Vimentin_8.png
# Now val_reg012_8_reg012_cyc014_ch003_CD40_8.png
# Now selected_mouse4_0701_reg001_cyc002_ch001_DAPI.png
# Now selected_mouse4_0701_reg001_cyc006_ch003_Ly6C.png
# Now selected_mouse4_0701_reg001_cyc009_ch004_ScaI.png
# Now selected_mouse4_0701_reg001_cyc007_ch004_CD45.png
# Now selected_mouse4_0701_reg001_cyc012_ch003_CD4.png
# Now selected_mouse4_0701_reg001_cyc013_ch004_N-Cadherin.png
# Now train_reg012_4_reg012_cyc011_ch003_CD163_4.png
# Now train_reg012_4_reg012_cyc012_ch003_MPO_4.png
# Now train_reg012_4_reg012_cyc011_ch004_CD45RA_4.png
# Now train_reg012_4_reg012_cyc017_ch004_NAKATP_4.png
# Now train_reg012_4_reg012_cyc017_ch003_CD11C_4.png
# Now train_reg012_4_reg012_cyc010_ch002_HSA_4.png
# Now train_reg012_4_reg012_cyc002_ch004_PD1_4.png
# Now train_reg012_4_reg012_cyc019_ch004_Vimentin_4.png
# Now train_reg012_4_reg012_cyc008_ch003_CD56_4.png
# Now train_reg012_4_reg012_cyc009_ch004_B-Catenin_4.png
# Now train_reg012_4_reg012_cyc005_ch003_CD15_4.png
# Now train_reg012_4_reg012_cyc006_ch003_PDL2_4.png
# Now train_reg012_4_reg012_cyc019_ch003_CD38_4.png
# Now train_reg012_4_reg012_cyc009_ch002_CK8CK18_4.png
# Now train_reg012_4_reg012_cyc016_ch003_Granzyme B_4.png
# Now train_reg012_4_reg012_cyc015_ch003_CD31_4.png
# Now train_reg012_4_reg012_cyc010_ch003_CD45RO_4.png
# Now train_reg012_4_reg012_cyc009_ch003_CD57_4.png
# Now train_reg012_4_reg012_cyc006_ch002_HLADR_4.png
# Now train_reg012_4_reg012_cyc010_ch004_TIM-3_4.png
# Now train_reg012_4_reg012_cyc014_ch003_CD40_4.png
# Now train_reg012_4_reg012_cyc014_ch004_Podoplanin_4.png
# Now train_reg012_4_reg012_cyc006_ch004_CD206_4.png
# Now train_reg012_4_reg012_cyc016_ch004_CD21_4.png
# Now train_reg012_4_reg012_cyc008_ch004_CD11b_4.png
# Now train_reg012_4_reg012_cyc003_ch003_CD8_4.png
# Now train_reg012_4_reg012_cyc004_ch003_FOXP3_4.png
# Now train_reg012_4_reg012_cyc003_ch002_KI67_4.png
# Now train_reg012_4_reg012_cyc011_ch002_CD68_4.png
# Now train_reg012_4_reg012_cyc005_ch004_GATA3_4.png
# Now train_reg012_4_reg012_cyc001_ch001_DAPI-01_4.png
# Now train_reg012_4_reg012_cyc013_ch003_E-Cadherin_4.png
# Now train_reg012_4_reg012_cyc018_ch004_Galectin-9_4.png
# Now train_reg012_4_reg012_cyc007_ch003_ICOS_4.png
# Now train_reg012_4_reg012_cyc002_ch003_PDL1_4.png
# Now train_reg012_4_reg012_cyc012_ch004_Panck_4.png
# Now train_reg012_4_reg012_cyc002_ch002_CD20_4.png
# Now train_reg012_4_reg012_cyc004_ch002_CD45_4.png
# Now train_reg012_4_reg012_cyc018_ch003_CD34_4.png
# Now train_reg012_4_reg012_cyc007_ch004_TP53_4.png
# Now train_reg012_4_reg012_cyc013_ch004_HSP-70_4.png
# Now train_reg012_4_reg012_cyc015_ch004_A-SMA_4.png
# Now train_reg012_4_reg012_cyc004_ch004_CD3e_4.png
# Now train_reg012_4_reg012_cyc003_ch004_CD4_4.png
# Now selected_mouse7_0701_reg001_cyc002_ch001_DAPI.png
# Now selected_mouse7_0701_reg001_cyc006_ch003_Ly6C.png
# Now selected_mouse7_0701_reg001_cyc009_ch004_ScaI.png
# Now selected_mouse7_0701_reg001_cyc007_ch004_CD45.png
# Now selected_mouse7_0701_reg001_cyc012_ch003_CD4.png
# Now selected_mouse7_0701_reg001_cyc013_ch004_N-Cadherin.png
# Now selected_mouse21_0701_reg001_cyc002_ch001_DAPI.png
# Now selected_mouse21_0701_reg001_cyc006_ch003_Ly6C.png
# Now selected_mouse21_0701_reg001_cyc009_ch004_ScaI.png
# Now selected_mouse21_0701_reg001_cyc007_ch004_CD45.png
# Now selected_mouse21_0701_reg001_cyc012_ch003_CD4.png
# Now selected_mouse21_0701_reg001_cyc013_ch004_N-Cadherin.png
# Now train_human0_reg006_cyc016_ch004_CD21_0.png
# Now train_human0_reg006_cyc010_ch002_HSA_0.png
# Now train_human0_reg006_cyc008_ch004_CD11b_0.png
# Now train_human0_reg006_cyc010_ch003_CD45RO_0.png
# Now train_human0_reg006_cyc001_ch001_DAPI-01_0.png
# Now train_human0_reg006_cyc018_ch004_Galectin-9_0.png
# Now train_human0_reg006_cyc003_ch003_CD8_0.png
# Now train_human0_reg006_cyc019_ch004_Vimentin_0.png
# Now train_human0_reg006_cyc007_ch003_ICOS_0.png
# Now train_human0_reg006_cyc017_ch003_CD11C_0.png
# Now train_human0_reg006_cyc006_ch004_CD206_0.png
# Now train_human0_reg006_cyc014_ch003_CD40_0.png
# Now train_human0_reg006_cyc013_ch004_HSP-70_0.png
# Now train_human0_reg006_cyc004_ch003_FOXP3_0.png
# Now train_human0_reg006_cyc013_ch003_E-Cadherin_0.png
# Now train_human0_reg006_cyc008_ch003_CD56_0.png
# Now train_human0_reg006_cyc015_ch004_A-SMA_0.png
# Now train_human0_reg006_cyc012_ch004_Panck_0.png
# Now train_human0_reg006_cyc007_ch004_TP53_0.png
# Now train_human0_reg006_cyc006_ch003_PDL2_0.png
# Now train_human0_reg006_cyc014_ch004_Podoplanin_0.png
# Now train_human0_reg006_cyc009_ch003_CD57_0.png
# Now train_human0_reg006_cyc002_ch004_PD1_0.png
# Now train_human0_reg006_cyc005_ch004_GATA3_0.png
# Now train_human0_reg006_cyc011_ch004_CD45RA_0.png
# Now train_human0_reg006_cyc012_ch003_MPO_0.png
# Now train_human0_reg006_cyc004_ch002_CD45_0.png
# Now train_human0_reg006_cyc015_ch003_CD31_0.png
# Now train_human0_reg006_cyc006_ch002_HLADR_0.png
# Now train_human0_reg006_cyc010_ch004_TIM-3_0.png
# Now train_human0_reg006_cyc002_ch002_CD20_0.png
# Now train_human0_reg006_cyc011_ch002_CD68_0.png
# Now train_human0_reg006_cyc016_ch003_Granzyme B_0.png
# Now train_human0_reg006_cyc004_ch004_CD3e_0.png
# Now train_human0_reg006_cyc009_ch002_CK8CK18_0.png
# Now train_human0_reg006_cyc009_ch004_B-Catenin_0.png
# Now train_human0_reg006_cyc017_ch004_NAKATP_0.png
# Now train_human0_reg006_cyc019_ch003_CD38_0.png
# %%
Image.open("./NTUH_test/0913_reg013_8_reg013_cyc001_ch001_DAPI-01_8_cp_masks.png").convert("L")
# Out:
# <PIL.Image.Image image mode=L size=672x756 at 0x7FA8C003D450>

# %% [markdown]
# ## after infer, put channels in same image back together

# %%
import shutil

# %%
infer_folder = "./NTUH_test/"
infer_imgs = [f for f in os.listdir(infer_folder) if "_masks" in f]

# %%
for img_name in test_folder_list:
    organized_path = "./NTUH_test_organized/{}/".format(img_name)
    if not os.path.isdir(organized_path):
        os.mkdir(organized_path)

    for infer_img in infer_imgs:
        if img_name in infer_img:
            source_path = infer_folder + infer_img
            dest_path = organized_path + infer_img
            shutil.copyfile(source_path, dest_path)

# %% [markdown]
# ## for each image, stack masks from each channel

# %%
for img_name in test_folder_list:
    organized_path = "./NTUH_test_organized/{}/".format(img_name)
    if os.path.isdir(organized_path):
        channels = [f for f in os.listdir(organized_path) if not f.startswith('.')]
        blank_img = np.zeros_like(np.array(Image.open(organized_path+channels[0])))
        cell_count = 1
        for channel in channels:
            if "DAPI" not in channel and "Ch1Cy1" not in channel:
                img = np.array(Image.open(organized_path+channel))
                ## print("channel {} max {}".format(channel, np.max(img)))
                for i in range(1, np.max(img)+1):
                    if not np.any(np.logical_and(img == i, blank_img > 0)):
                        blank_img[img == i] = cell_count
                        cell_count += 1
        result_img = Image.fromarray(blank_img*255).convert("L")
        result_img.save("./NTUH_test_processed/{}.png".format(img_name))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-35eb6dee8f1e> in <module>
#       3     if os.path.isdir(organized_path):
#       4         channels = [f for f in os.listdir(organized_path) if not f.startswith('.')]
# ----> 5         blank_img = np.zeros_like(np.array(Image.open(organized_path+channels[0])))
#       6         cell_count = 1
#       7         for channel in channels:
#
# IndexError: list index out of range

# %%
tmp = np.load("./NTUH_test/0913_reg013_18_reg013_cyc002_ch002_CD20_18_seg.npy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-a6eb7f2c2b3b> in <module>
# ----> 1 tmp = np.load("./NTUH_test/0913_reg013_18_reg013_cyc002_ch002_CD20_18_seg.npy")
#
# ~/miniconda3/envs/unet/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     439             else:
#     440                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 441                                          pickle_kwargs=pickle_kwargs)
#     442         else:
#     443             # Try a pickle
#
# ~/miniconda3/envs/unet/lib/python3.7/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     737         # The array contained Python objects. We need to unpickle the data.
#     738         if not allow_pickle:
# --> 739             raise ValueError("Object arrays cannot be loaded when "
#     740                              "allow_pickle=False")
#     741         if pickle_kwargs is None:
#
# ValueError: Object arrays cannot be loaded when allow_pickle=False

# %%
tmp2 = np.ndarray.tolist(tmp)

# %%
np.max(tmp2['masks'])
# Out:
# 4

# %%
Image.fromarray(tmp2['masks']*255).convert("L")
# Out:
# <PIL.Image.Image image mode=L size=672x756 at 0x7FA8D1C99FD0>

# %%
tmp_img = Image.open("./NTUH_test_organized/0913_reg013_18/0913_reg013_18_reg013_cyc002_ch002_CD20_18_cp_masks.png")

# %%
Image.fromarray(np.array(tmp_img.convert("L"))*255)
# Out:
# <PIL.Image.Image image mode=L size=672x756 at 0x7FA8A4565B90>
